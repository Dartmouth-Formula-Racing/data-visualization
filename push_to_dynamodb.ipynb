# %%
import awswrangler as wr

# %%
wr.dynamodb
# Out:
# <module 'awswrangler.dynamodb' from '/Users/henryscheible/PycharmProjects/data-visualization/venv/lib/python3.9/site-packages/awswrangler/dynamodb/__init__.py'>

# %%
import pandas as pd

# %%
df = pd.DataFrame({
    "key": [1,2],
    "value":["foo", "boo"]
})
wr.dynamodb.put_df(df=df, table_name="table")
# Out:
# ---------------------------------------------------------------------------
# NoRegionError                             Traceback (most recent call last)
# Cell In[6], line 5
#       1 df = pd.DataFrame({
#       2     "key": [1,2],
#       3     "value":["foo", "boo"]
#       4 })
# ----> 5 wr.dynamodb.put_df(df=df, table_name="table")
#
# File ~/PycharmProjects/data-visualization/venv/lib/python3.9/site-packages/awswrangler/_config.py:472, in apply_configs.<locals>.wrapper(*args_raw, **kwargs)
#     470         del args[name]
#     471         args = {**args, **keywords}
# --> 472 return function(**args)
#
# File ~/PycharmProjects/data-visualization/venv/lib/python3.9/site-packages/awswrangler/dynamodb/_write.py:151, in put_df(df, table_name, boto3_session)
#     122 """Write all items from a DataFrame to a DynamoDB.
#     123
#     124 Parameters
#    (...)
#     147 ... )
#     148 """
#     149 items: List[Mapping[str, Any]] = [v.dropna().to_dict() for k, v in df.iterrows()]
# ...
